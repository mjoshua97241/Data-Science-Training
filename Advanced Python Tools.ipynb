# %% [markdown]
# # Object-Oriented Programming (OOP)
#
# This 🔍focus on the _object_
#
# Every value in python is an _object_:
# - Floats
# - Integers
# - Strings
# - Lists...
#
# Object = Data + Manipulation Operations

# %% [markdown]
# - Each object belongs to _class_ (defines the rules for creating that object)
#
# Diagram:
#
# ![image.png](attachment:b68c8df3-36d0-422e-bb16-fe597f110df7.png)
#
# - Method - is consequential sequence
#
# Example:
#
# ![image.png](attachment:aac467db-1aa2-454d-9e1e-55db9c2d23d7.png)
#
# ![image.png](attachment:30038de7-6970-4f13-862c-7699bd9cfbd6.png)

# %% [markdown]
# Function vs Method
#
# ![image.png](attachment:d1b0e284-c0c1-4ed5-af4c-abc64b3d2677.png)
