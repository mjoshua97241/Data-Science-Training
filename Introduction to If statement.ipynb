# %% [markdown]
# # Introduction to the If Statement
#
# ![image.png](attachment:621c70a5-c092-4c57-8961-b53dab775374.png)

# %%
if 5 == 15 / 3:
    print("Hooray!")
# Out:
# Hooray!

# %%
if 5 == 18 / 3:
    print("Hooray!")

# %%
if 5 != 3 * 6:
    print("Hooray!")
# Out:
# Hooray!

# %% [markdown]
# # Else Statement

# %%
x = 1

if x > 3:
    print("Case 1")
else:
    print("Case 2")
# Out:
# Case 2
