# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv('1.01. Simple linear regression.csv')

# %%
data
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
data.describe()
# Out:
#                SAT        GPA
# count    84.000000  84.000000
# mean   1845.273810   3.330238
# std     104.530661   0.271617
# min    1634.000000   2.400000
# 25%    1772.000000   3.190000
# 50%    1846.000000   3.380000
# 75%    1934.000000   3.502500
# max    2050.000000   3.810000

# %% [markdown]
# Each time you create a regression, it should be _meaningful_.
#
# "Why should I predict GPA with SAT?"
# 1. The SAT is considered one of the best estimators of intellectual capacity and capability.
# 2. Almost all colleges across the USA are using the SAT as a proxy admission.
# 3. The SAT stood the test of time.

# %% [markdown]
# # Create your first regression
#
# ### Define the dependent and the independent variables
#
# Linear Regression equation y^ = $b_{0}$ + $b_{1}$$x_{1}$

# %%
y = data['GPA']
x1 = data['SAT']

# %% [markdown]
# ### Explore the data

# %%
plt.scatter(x1, y)
plt.xlabel('SAT', fontsize=20)
plt.ylabel('GPA', fontsize=20)
plt.show()

# %% [markdown]
# The higher the SAT of the student, the higher their GPA

# %% [markdown]
# ### Regression itself

# %%
x = sm.add_constant(x1)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GPA   R-squared:                       0.406
# Model:                            OLS   Adj. R-squared:                  0.399
# Method:                 Least Squares   F-statistic:                     56.05
# Date:                Sun, 05 Jan 2025   Prob (F-statistic):           7.20e-11
# Time:                        05:28:50   Log-Likelihood:                 12.672
# No. Observations:                  84   AIC:                            -21.34
# Df Residuals:                      82   BIC:                            -16.48
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2750      0.409      0.673      0.503      -0.538       1.088
# ...

# %%
plt.scatter(x1, y)
yhat = 0.0017*x1 + 0.275
fig = plt.plot(x1, yhat, lw=4, c='red', label='regression line')
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('GPA', fontsize = 20)
plt.show()

# %%
hat = 0.0017*1850
hat
# Out:
# 3.145

# %% [markdown]
# ![image.png](attachment:4d602dce-bf67-4f6a-8967-c829a0cfdae7.png)

# %% [markdown]
# ## $R^{2}$ = SSR / SST

# %% [markdown]
# ![image.png](attachment:159a64ba-00dc-400f-9676-312b5646fe7f.png)

# %% [markdown]
# No rule of thumb to determine the $R^{2}$. It depends on the complexity of the topic and how many variables in play.
#
# ![image.png](attachment:e9798635-caf9-4b7f-b020-234aa2359f32.png)

# %% [markdown]
# Example: Income
#
# ![image.png](attachment:740ab298-cd68-4c77-9f7d-88978f6cc9bf.png)

# %%
# R2 = SSR / SST
R2 = 945/1245
R2
# Out:
# 0.7590361445783133
