# %% [markdown]
# # Market Segmentation Heatmap - Exercise

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv('3.12. Market Segmentation.csv')
data.head()
# Out:
#    Satisfaction  Loyalty
# 0             4    -1.33
# 1             6    -0.28
# 2             5    -0.99
# 3             7    -0.29
# 4             4     1.06

# %%
sns.clustermap(data, cmap='mako')
